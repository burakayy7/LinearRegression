# %% [markdown]
# <a href="https://colab.research.google.com/github/burakayy7/LinearRegression/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
x = [i for i in range(-110, 120, 10)]
y = [3*i-5 for i in x]
y = [i+(random.random()*250) for i in y]
df = pd.DataFrame({'a1': x, 'a2': y})
plt.scatter(df.a1, df.a2, color="black")

# %%
df.columns = ['a1', 'a2']
def mean_squared_error(m, b, points):
  total_error = 0
  for i in range (len(points)):
    x_i = points.iloc[i].a1
    y_i = points.iloc[i].a2
    total_error += (y_i - (m*x_i+b))**2
  total_error/float(len(points))

def gradient_descent(m_now, b_now, points, L):
  m_gradient = 0
  b_gradient = 0
  n = len(points)
  for i in range(n):
    x_i = points.iloc[i].a1
    y_i = points.iloc[i].a2
    m_gradient += -(2/n) *x_i*(y_i-(m_now*x_i+b_now))
    b_gradient += -(2/n) *(y_i-(m_now*x_i+b_now))
  m = m_now - m_gradient * L
  b = b_now - b_gradient * L
  return m, b

m = 0
b = 0
L = 0.0001
epoch = 200

for i in range(epoch):
  m, b = gradient_descent(m, b, df, L)
print(m, b)
plt.scatter(df.a1, df.a2, color="black")
plt.plot(list(range(-100, 110, 10)), [m*x+b for x in range(-100, 110, 10)], color="red")
plt.show()
# Out:
# 2.5857072211639407 3.399797600106841

# %%
# Out:
#      a1          a2
# 0  -100 -291.523262
# 1   -90 -185.480298
# 2   -80 -159.085215
# 3   -70 -136.688107
# 4   -60 -111.715942
# 5   -50 -107.720681
# 6   -40  -81.416487
# 7   -30  -33.739071
# 8   -20  -25.410035
# 9   -10  -22.195048
# 10    0   89.139719
# 11   10   29.401679
# 12   20  118.360589
# 13   30   94.044650
# 14   40  126.573238
# 15   50  205.762043
# 16   60  192.873540
# 17   70  283.217380
# 18   80  299.332594
# 19   90  312.719347
# 20  100  336.109331
